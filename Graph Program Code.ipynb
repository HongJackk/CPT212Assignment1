# %%
# %matplotlib notebook

# %% [markdown]
# # Number of Primitive Operations vs Number of Input (Constant Length)

# %% [markdown]
# ## Part 1 Graph

# %%
import matplotlib.pyplot as plt

# Dataset A
A = [
    (2, 4551),
    (3, 4924),
    (4, 5293),
    (5, 5662),
    (6, 6037),
    (7, 6406),
    (8, 6775)
]

# Extract x (Number of Input) and y (Primitive Operations)
x = [p[0] for p in A]
y = [p[1] for p in A]

# Plot setup
plt.figure(figsize=(8, 6))
plt.plot(x, y, color='blue')
plt.scatter(x, y, color='blue')

# Show the coordinate
for xi, yi in zip(x, y):
    plt.text(xi, yi + 90, f'({xi}, {yi})', ha='center', fontsize=9, color='black')

# Graph label
plt.xlabel('Number of Input', labelpad=15)
plt.ylabel('Number of Primitive Operation', labelpad=15)
plt.title('Number of Primitive Operations vs Number of Input (Constant Length - 3 Digit)')
plt.grid(True)
plt.tight_layout()

plt.show()

import numpy as np

x = np.array([2, 3, 4, 5, 6, 7, 8])
y = np.array([4551, 4924, 5293, 5662, 6037, 6406, 6775])

# Fit a line y = mx + c
m, c = np.polyfit(x, y, 1)
print(f"y = {m:.2f}x + {c:.2f}")
# Out:
# <img src="data:image/png;base64,..." width="800">
# y = 370.71x + 3810.43

# %% [markdown]
# ## Part 2 Graph

# %%
import matplotlib.pyplot as plt

# Dataset A
A = [
    (2, 75918),
    (3, 102463),
    (4, 129008),
    (5, 155553),
    (6, 182098),
    (7, 208643),
    (8, 235188)
]

# Extract x (Number of Input) and y (Primitive Operations)
x = [p[0] for p in A]
y = [p[1] for p in A]

# Plot setup
plt.figure(figsize=(8, 6))
plt.plot(x, y, color='blue')
plt.scatter(x, y, color='blue')

# Show the coordinate
for xi, yi in zip(x, y):
    plt.text(xi, yi + 5000, f'({xi}, {yi})', ha='center', fontsize=9, color='black')

# Graph label
plt.xlabel('Number of Input', labelpad=15)
plt.ylabel('Number of Primitive Operation', labelpad=15)
plt.title('Number of Primitive Operations vs Number of Input (Constant Length - 5 Letter)')
plt.grid(True)
plt.tight_layout()

plt.show()

import numpy as np

x = np.array([2, 3, 4, 5, 6, 7, 8])
y = np.array([75918, 102463, 129008, 155553, 182098, 208643, 235188])

# Fit a line y = mx + c
m, c = np.polyfit(x, y, 1)
print(f"y = {m:.0f}x + {c:.0f}")
# Out:
# <img src="data:image/png;base64,..." width="800">
# y = 26545x + 22828

# %% [markdown]
# # Number of Primitive Operations vs Maximum Length of Input (Constant Size)

# %% [markdown]
# ## Part 1 Graph

# %%
import matplotlib.pyplot as plt

# Dataset A
A = [
    (2, 3294),
    (3, 4922),
    (4, 6550),
    (5, 8176),
    (6, 9804),
    (7, 11432),
    (8, 13062)
]

# Extract x (Maximum length of input) and y (Primitive Operations)
x = [p[0] for p in A]
y = [p[1] for p in A]

# Plot setup
plt.figure(figsize=(8, 6))
plt.plot(x, y, color='blue')
plt.scatter(x, y, color='blue')

# Show the coordinate
for xi, yi in zip(x, y):
    plt.text(xi, yi + 200, f'({xi}, {yi})', ha='center', fontsize=9, color='black')

# Graph label    
plt.xlabel('Maximum Length of Input', labelpad=15)
plt.ylabel('Number of Primitive Operation', labelpad=15)
plt.title('Number of Primitive Operations vs Maximum Length of Input (Constant Size - 3 Input)')
plt.grid(True)
plt.tight_layout()

plt.show()

import numpy as np

x = np.array([2, 3, 4, 5, 6, 7, 8])
y = np.array([3294, 4922, 6550, 8176, 9804, 11432, 13062])

# Fit a line y = mx + c
m, c = np.polyfit(x, y, 1)
print(f"y = {m:.2f}x + {c:.2f}")
# Out:
# <img src="data:image/png;base64,..." width="800">
# y = 1627.79x + 38.21

# %% [markdown]
# ## Part 2 Graph

# %%
import matplotlib.pyplot as plt

# Dataset A
A = [
    (2, 40999),
    (3, 61487),
    (4, 81975),
    (5, 102463),
    (6, 122951),
    (7, 143439),
    (8, 163927)
]

# Extract x (Maximum length of input) and y (Primitive Operations)
x = [p[0] for p in A]
y = [p[1] for p in A]

# Plot setup
plt.figure(figsize=(8, 6))
plt.plot(x, y, color='blue')
plt.scatter(x, y, color='blue')

# Show the coordinate
for xi, yi in zip(x, y):
    plt.text(xi, yi + 5000, f'({xi}, {yi})', ha='center', fontsize=9, color='black')

# Graph label    
plt.xlabel('Maximum Length of Input', labelpad=15)
plt.ylabel('Number of Primitive Operation', labelpad=15)
plt.title('Number of Primitive Operations vs Maximum Length of Input (Constant Size - 3 Input)')
plt.grid(True)
plt.tight_layout()

plt.show()

import numpy as np

x = np.array([2, 3, 4, 5, 6, 7, 8])
y = np.array([40999, 61487, 81975, 102463, 122951, 143439, 163927])

# Fit a line y = mx + c
m, c = np.polyfit(x, y, 1)
print(f"y = {m:.0f}x + {c:.0f}")
# Out:
# <img src="data:image/png;base64,..." width="800">
# y = 20488x + 23
